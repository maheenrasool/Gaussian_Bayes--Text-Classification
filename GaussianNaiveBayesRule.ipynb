# %% [markdown]
# # Assignment No 2b
# #### Assignment Credit
# ###### *Dr. Sibt ul Hussain*
# ----
# ## Goal
#
# Your goal in this assigment is to implement a Gaussian **Naive** Bayes Classifier.

# %% [markdown]
# Naive Bayes Rule
# ==============

# %% [markdown]
# ### Instructions
# - Do not modify the block with test cases.
# - Do not tailor your solution to only pass the test cases. We will use different data for grading so keep your solution generic.
# - Passing all the cases means you are in reight direction, but does not ensure 100% marks, there may be some other cases hidden, so carefully read the question statement and implement all the necessory functionality.
# - <p style="color:#ff0000">Plagiarism of any kind, (including internet) will lead to zero marks.</p>
#
# #### Libraries
# Ther are two additional libraries used which are not included in Anaconda package, nose and seaborn. You can install them using the following commands :
# ```sh
# conda install -c anaconda nose=1.3.7
# conda install -c anaconda seaborn=0.7.1
# ```
# Version of different libraries used are listed below:
# - Matplotlib **1.5.1**
# - Pandas **0.18.1**
# - Numpy **1.11.1**
# - Scipy **0.17.1**
# - Seaborn **0.7.1**
#
# Code for checking version info is present in cell below.
#
# #### Dead Kernal
# In case kernel does not connect, and shows a dead kernal meggese in read :
# - Go to Kernal -> Change kernal, and choose any of the available kernels.
# - Press ctrl + s and close the tab.
# - Open the notebook again and the kernel will connect. If it still does not connect then go to Kernel -> restart.
#
#
# **Note : ** Accuracies may slightly vary due to randomness in train-text split.

# %%
# %pylab inline
import scipy.stats
import pandas as pd
import numpy as np
from collections import defaultdict
import seaborn as sns
#many important functions are already written and provided in tools.py 
# please have a look at these functions....
import tools as t


plt.style.use('ggplot')
matplotlib.rcParams['figure.figsize'] = (10.0, 8.0)
# %load_ext autoreload 
# %autoreload 2
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
print ("Matplotlib version : ", matplotlib.__version__)
print ("Pandas version : ", pd.__version__)
print ("Numpy version : ", np.__version__)
print ("Scipy version : ", scipy.__version__)
print ("Seaborn version : ", sns.__version__)
# Out:
# Matplotlib version :  3.8.4
# Pandas version :  2.2.2
# Numpy version :  1.26.4
# Scipy version :  1.13.1
# Seaborn version :  0.13.2

# %%
help(scipy.stats.norm.pdf)
# Out:
# Help on method pdf in module scipy.stats._distn_infrastructure:
#
# pdf(x, *args, **kwds) method of scipy.stats._continuous_distns.norm_gen instance
#     Probability density function at x of the given RV.
#
#     Parameters
#     ----------
#     x : array_like
#         quantiles
#     arg1, arg2, arg3,... : array_like
#         The shape parameter(s) for the distribution (see docstring of the
#         instance object for more information)
#     loc : array_like, optional
#         location parameter (default=0)
#     scale : array_like, optional
#         scale parameter (default=1)
#
#     Returns
#     -------
#     pdf : ndarray
#         Probability density function evaluated at x

# %%
import math

def pdf(mean,var, p):
    
    z = (p - mean)#.reshape([-1,1])
    num = math.exp( -0.5 *  z**2 / var) 
    #print(num)
    denom = ((2 * math.pi * var) **1/2)
    #print(denom)
    fx = num/denom
    
    #print(fx)
    return float(fx)

# %%
# YOUR CODE HERE
#raise NotImplementedError()

class GaussianBayes:
    ''' Implements the Gaussian Bayes For Classification... '''
    def __init__(self):
        self.p_prior = {}
        self.mean = []
        self.variance = []
    def empty_mean(self):
        self.mean = []
    def variance_mean(self):
        self.variance = []
    def train(self, X, Y):
        ''' Train the multiclass (or Binary) Bayes Rule using the given 
            X [m x n] data matrix and Y labels matrix'''
        # assume the given features are independent
        # find the prior probabilities
        # find mean with respect to class of the two features
        # Since we have assumed that the features are independent the covariance will be 0 
        # so we will NOT find covariance matrix instead find variance only
        # use gaussian formula for univariate to find likelihood probabilities 
        # is P(c1/x) = P(x1/c1) * P(X2/C2) ...? not P(c1/x) = P(x1/c1) * P(X2/C1) ...* p(C1) we don't multiply with prior probability? 
        
        # YOUR CODE HERE
        idx_set = np.where(Y == 'Iris-setosa')
        idx_vir = np.where(Y == 'Iris-virginica')
        idx_ver = np.where(Y == 'Iris-versicolor')
        indices = [idx_set, idx_vir, idx_ver]
        
        
        self.empty_mean() #empty it to calculate the new mean 
        for i in range(3):
            f = []
            for j in range(X.shape[1]):
                rows = X[indices[i], :][0]
                f.append(rows[: , j].mean()) 
            self.mean.append(f)

        self.p_prior = dict.fromkeys(np.unique(Y), 0)
        
        for i in np.unique(Y):     #finding prior probabilities
            self.p_prior[i] = len(np.where(Y == i))/ len(Y)
        
        #print("Mean shape: ", self.mean)
        self.variance_mean()
        for i in range(3):
            f = []
            for j in range(X.shape[1]):
                rows = X[indices[i], :][0] 
                f.append(rows[: , j].var()) 
            self.variance.append(f)
        #print("Var shape: ", self.variance)
        
    def test(self, X):
        
        ''' Run the trained classifiers on the given set of examples 
            For each example, you should return probability and its assigned class
            Input: X of m x d
            Output:
            pclasses: predicted class of each example
            probability: probability of each example falling in that predicted class...
        '''
        
        # nexamples, nfeatures=X.shape
        # res=np.zeros((nexamples,self.nclasses))
        # pclasses=[0]*nexamples

         
        # probability of class given feature
        probability = []
        pclasses = []
        labels = np.unique(Y)
        for p in X:
            #print("Point: ", p.shape)
            #print("mean: ", np.array(self.mean[0])
            prob = []
            for i in range(len(labels)):
                P = 1
                for j in range(len(p)):
                    P *= (pdf(np.array(self.mean[i][j]),self.variance[i][j], p[j] ))
                P = P * self.p_prior[labels[i]] # when multiplied with all features multiply with prior of class
                prob.append(P)
            idx = np.argmax(prob)
            probability.append(prob[idx])

            if idx == 0:
                pclasses.append('Iris-setosa')
                
            elif idx == 1:
                pclasses.append('Iris-virginica')
                
            elif idx == 2:
                pclasses.append('Iris-versicolor')
        print(labels)
                
            
            
            
        return np.array(pclasses), np.array(probability)
        
        # YOUR CODE HERE
        raise NotImplementedError()
        return np.array(pclasses), res
    
    def predict(self, X):
        return self.test(X)[0]

# %%
# # Lets train a Gaussian Bayes Classifier on Petal Length and Width
# gb=GaussianBayes()
# gb.train(Xtrain[:,2:],Ytrain)
# gb.test(Xtest[:,2:])

# %%
data=pd.read_csv('./iris.data')
data.columns=['SepalLength','SepalWidth','PetalLength','PetalWidth','Class']
print (data.describe())
# Out:
#        SepalLength  SepalWidth  PetalLength  PetalWidth
# count   149.000000  149.000000   149.000000  149.000000
# mean      5.848322    3.051007     3.774497    1.205369
# std       0.828594    0.433499     1.759651    0.761292
# min       4.300000    2.000000     1.000000    0.100000
# 25%       5.100000    2.800000     1.600000    0.300000
# 50%       5.800000    3.000000     4.400000    1.300000
# 75%       6.400000    3.300000     5.100000    1.800000
# max       7.900000    4.400000     6.900000    2.500000

# %% [markdown]
# #### Get your data in matrix

# %%
X=np.asarray(data[['SepalLength','SepalWidth','PetalLength','PetalWidth']].dropna())
Y=np.asarray(data['Class'].dropna())
print (" Data Set Dimensions=", X.shape, " True Class labels dimensions", Y.shape)
# Out:
#  Data Set Dimensions= (149, 4)  True Class labels dimensions (149,)

# %% [markdown]
# #### Let's Plot the Data

# %%
#Lets plot the Complete data, with its covariance matrix...
# Remember seeing is believing
featnames=data.columns
t.plotCov(X[:,2:],Y,labels=featnames.values[2:4])

# %% [markdown]
# ### Splitting the Data into Training and Testing Sets
# There must be a validation set but for this case we are using only two sets, training and validation sets...

# %%
# Split your data into training and test-set... 
# see the documentation of split_data in tools for further information...
Xtrain,Ytrain,Xtest,Ytest=t.split_data(X,Y)

print (" Training Data Set Dimensions=", Xtrain.shape, "Training True Class labels dimensions", Ytrain.shape)
print (" Test Data Set Dimensions=", Xtest.shape, "Test True Class labels dimensions", Ytrain.shape)
# Out:
#  Training Data Set Dimensions= (104, 4) Training True Class labels dimensions (104,)
#  Test Data Set Dimensions= (45, 4) Test True Class labels dimensions (104,)

# %%
#Lets plot the training data...
t.plotCov(Xtrain[:,2:],Ytrain, labels=featnames.values[2:4])
# so we will be estimating these covariance matrices and means...

# %%
#Lets plot the test data...
t.plotCov(Xtest[:,2:],Ytest,labels=featnames.values[2:4])

# %% [markdown]
# Training Time
# ========
# Let's train a Gaussian Bayes, first using two attributes.
# - What Two Attributes to use ? Any Guess...

# %%
# Lets train a Gaussian Bayes Classifier on Petal Length and Width
gb=GaussianBayes()
gb.train(Xtrain[:,2:],Ytrain)

# %%
#Lets test it on the set of unseen examples...
pclasses,res=gb.test(Xtest[:,2:])
# Out:
# ['Iris-setosa' 'Iris-versicolor' 'Iris-virginica']

# %% [markdown]
# Lets see how good we are doing...
# ==================

# %%
#Lets see how good we are doing...
print (pclasses==Ytest)
print (Ytest.shape[0])
# Out:
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True False  True  True
#  False  True  True  True  True  True  True  True  True]
# 45

# %%
# Using Just two attributes, accuracy is 
print (np.sum(pclasses==Ytest))
print ("Accuracy = ", np.sum(pclasses==Ytest)/float(Ytest.shape[0]))
# Out:
# 43
# Accuracy =  0.9555555555555556

# %%
print (" Plotting the Decision Surface of Training Set... ")
t.plot_decision_regions(Xtrain[:,2:],Ytrain,clf=gb, res=0.02, cycle_marker=True, legend=1)
# Out:
#  Plotting the Decision Surface of Training Set...
# ['Iris-setosa' 'Iris-versicolor' 'Iris-virginica']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[232], line 2
#       1 print (" Plotting the Decision Surface of Training Set... ")
# ----> 2 t.plot_decision_regions(Xtrain[:,2:],Ytrain,clf=gb, res=0.02, cycle_marker=True, legend=1)
#
# File ~\Downloads\i220626_A2_AI-B_ML\i220626_A2_AI-B_ML\Fall24_assignment-2\tools.py:685, in plot_decision_regions(X, y, clf, res, cycle_marker, legend)
#     683 	Z=np.array(Z);
#     684 Z = Z.reshape(xx.shape);
# --> 685 plt.contourf(xx, yy, Z, alpha=0.4, cmap=cmap)
#     686 plt.xlim(xx.min(), xx.max())
#     687 plt.ylim(yy.min(), yy.max())
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\pyplot.py:2950, in contourf(data, *args, **kwargs)
#    2948 @_copy_docstring_and_deprecators(Axes.contourf)
#    2949 def contourf(*args, data=None, **kwargs) -> QuadContourSet:
# -> 2950     __ret = gca().contourf(
#    2951         *args, **({"data": data} if data is not None else {}), **kwargs
#    2952     )
#    2953     if __ret._A is not None:  # type: ignore[attr-defined]
#    2954         sci(__ret)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\__init__.py:1465, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1462 @functools.wraps(func)
#    1463 def inner(ax, *args, data=None, **kwargs):
#    1464     if data is None:
# -> 1465         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1467     bound = new_sig.bind(ax, *args, **kwargs)
#    1468     auto_label = (bound.arguments.get(label_namer)
#    1469                   or bound.kwargs.get(label_namer))
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:6536, in Axes.contourf(self, *args, **kwargs)
#    6527 """
#    6528 Plot filled contours.
#    6529
#    (...)
#    6533 %(contour_doc)s
#    6534 """
#    6535 kwargs['filled'] = True
# -> 6536 contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    6537 self._request_autoscale_view()
#    6538 return contours
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\contour.py:858, in ContourSet.__init__(self, ax, levels, filled, linewidths, linestyles, hatches, alpha, origin, extent, cmap, colors, norm, vmin, vmax, extend, antialiased, nchunk, locator, transform, negative_linestyles, clip_path, *args, **kwargs)
#     854 if self.negative_linestyles is None:
#     855     self.negative_linestyles = \
#     856         mpl.rcParams['contour.negative_linestyle']
# --> 858 kwargs = self._process_args(*args, **kwargs)
#     859 self._process_levels()
#     861 self._extend_min = self.extend in ['min', 'both']
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\contour.py:1523, in QuadContourSet._process_args(self, corner_mask, algorithm, *args, **kwargs)
#    1520         corner_mask = mpl.rcParams['contour.corner_mask']
#    1521 self._corner_mask = corner_mask
# -> 1523 x, y, z = self._contour_args(args, kwargs)
#    1525 contour_generator = contourpy.contour_generator(
#    1526     x, y, z, name=self._algorithm, corner_mask=self._corner_mask,
#    1527     line_type=contourpy.LineType.SeparateCode,
#    1528     fill_type=contourpy.FillType.OuterCode,
#    1529     chunk_size=self.nchunk)
#    1531 t = self.get_transform()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\contour.py:1567, in QuadContourSet._contour_args(self, args, kwargs)
#    1565 else:
#    1566     raise _api.nargs_error(fn, takes="from 1 to 4", given=nargs)
# -> 1567 z = ma.masked_invalid(z, copy=False)
#    1568 self.zmax = z.max().astype(float)
#    1569 self.zmin = z.min().astype(float)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\numpy\ma\core.py:2360, in masked_invalid(a, copy)
#    2333 """
#    2334 Mask an array where invalid values occur (NaNs or infs).
#    2335
#    (...)
#    2357
#    2358 """
#    2359 a = np.array(a, copy=False, subok=True)
# -> 2360 res = masked_where(~(np.isfinite(a)), a, copy=copy)
#    2361 # masked_invalid previously never returned nomask as a mask and doing so
#    2362 # threw off matplotlib (gh-22842).  So use shrink=False:
#    2363 if res._mask is nomask:
#
# TypeError: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %% [markdown]
# ### Test Cases for your classifier

# %%
from nose.tools import assert_greater_equal, assert_is_not_none
import pandas as pd
data=pd.read_csv('./iris.data')
data.columns=['SepalLength','SepalWidth','PetalLength','PetalWidth','Class']
X=np.asarray(data[['SepalLength','SepalWidth','PetalLength','PetalWidth']].dropna())
Y=np.asarray(data['Class'].dropna())

data_val = pd.read_csv('./iris_val.data')
data_val.columns = ['SepalLength','SepalWidth','PetalLength','PetalWidth','Class']
X_val = np.asarray(data_val[['SepalLength','SepalWidth','PetalLength','PetalWidth']].dropna())
Y_val = np.asarray(data_val['Class'].dropna())

gb_val=GaussianBayes()
gb_val.train(X[:,2:],Y)
pclasses_val, _ = gb_val.test(X_val[:,2:])
acc_val = np.sum(pclasses_val == Y_val) / float(pclasses_val.shape[0])

assert_greater_equal(acc_val, 0.90, msg="Acc must be greater then 90%")

cls =gb.predict(np.array([2,2]).reshape((1,2)))
assert_is_not_none(cls, msg="Predict should work for single example")

print ("All cases passed !")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 from nose.tools import assert_greater_equal, assert_is_not_none
#       2 import pandas as pd
#       3 data=pd.read_csv('./iris.data')
#
# File C:\ProgramData\anaconda3\Lib\site-packages\nose\__init__.py:1
# ----> 1 from nose.core import collector, main, run, run_exit, runmodule
#       2 # backwards compatibility
#       3 from nose.exc import SkipTest, DeprecatedTest
#
# File C:\ProgramData\anaconda3\Lib\site-packages\nose\core.py:12
#       9 import unittest
#      11 from nose.config import Config, all_config_files
# ---> 12 from nose.loader import defaultTestLoader
#      13 from nose.plugins.manager import PluginManager, DefaultPluginManager, \
#      14      RestrictedPluginManager
#      15 from nose.result import TextTestResult
#
# File C:\ProgramData\anaconda3\Lib\site-packages\nose\loader.py:21
#      19 from nose.failure import Failure
#      20 from nose.config import Config
# ---> 21 from nose.importer import Importer, add_path, remove_path
#      22 from nose.selector import defaultSelector, TestAddress
#      23 from nose.util import func_lineno, getpackage, isclass, isgenerator, \
#      24     ispackage, regex_last_key, resolve_name, transplant_func, \
#      25     transplant_class, test_address
#
# File C:\ProgramData\anaconda3\Lib\site-packages\nose\importer.py:12
#       9 import sys
#      10 from nose.config import Config
# ---> 12 from imp import find_module, load_module, acquire_lock, release_lock
#      14 log = logging.getLogger(__name__)
#      16 try:
#
# ModuleNotFoundError: No module named 'imp'

# %% [markdown]
# ## Question: What can you conclude from the above decision Region

# %% [markdown]
# # K-Fold Cross Validation
#
# Since our dataset is not too big, to ensure that we are reporting true picture of our classifier,
# we will have to cross validate and report the mean accuracy across the folds to reflect the true
# picture of our classifier.

# %%
# Now lets cross validate, and test the result...
nfolds=4
folds=t.generate_folds(X,Y,nfolds)

#now lets train and test on these folds...
totacc=[]
for k in range(nfolds):
    gb=GaussianBayes()
    gb.train(folds[k][0][:,2:],folds[k][1])
    pclasses,res=gb.test(folds[k][2][:,2:])
    acc=np.sum(pclasses==folds[k][3])/float(folds[k][3].shape[0])
    print ("[Info] Fold {} Accuracy = {}".format(k+1, acc))
    totacc.append(acc)

print (totacc, 'Mean Accuracy =', np.mean(totacc))
# Out:
# Generating CV data for 3 classes
# ['Iris-setosa' 'Iris-versicolor' 'Iris-virginica']
# [Info] Fold 1 Accuracy = 0.9722222222222222
# ['Iris-setosa' 'Iris-versicolor' 'Iris-virginica']
# [Info] Fold 2 Accuracy = 0.9444444444444444
# ['Iris-setosa' 'Iris-versicolor' 'Iris-virginica']
# [Info] Fold 3 Accuracy = 0.9722222222222222
# ['Iris-setosa' 'Iris-versicolor' 'Iris-virginica']
# [Info] Fold 4 Accuracy = 0.9722222222222222
# [0.9722222222222222, 0.9444444444444444, 0.9722222222222222, 0.9722222222222222] Mean Accuracy = 0.9652777777777778

# %% [markdown]
# Hmm Quite Impressive...
# --------------------------------

# %%
# Lets go and use all the four attributes...
gb.train(Xtrain,Ytrain)

# %%
pclasses,res=gb.test(Xtest)
# Out:
# ['Iris-setosa' 'Iris-versicolor' 'Iris-virginica']

# %% [markdown]
# #### Do you expect your Test accuracy to increase or decrease ?

# %%
# Using all four attributes, accuracy is 
print ("Accuracy = ", np.sum(pclasses==Ytest)/float(Ytest.shape[0]))
# Out:
# Accuracy =  0.9555555555555556

# %% [markdown]
# ### Test cases for all features

# %%
from nose.tools import assert_greater_equal, assert_is_not_none
import pandas as pd
data=pd.read_csv('./iris.data')
data.columns=['SepalLength','SepalWidth','PetalLength','PetalWidth','Class']
X=np.asarray(data[['SepalLength','SepalWidth','PetalLength','PetalWidth']].dropna())
Y=np.asarray(data['Class'].dropna())

data_val = pd.read_csv('./iris_val.data')
data_val.columns = ['SepalLength','SepalWidth','PetalLength','PetalWidth','Class']
X_val = np.asarray(data_val[['SepalLength','SepalWidth','PetalLength','PetalWidth']].dropna())
Y_val = np.asarray(data_val['Class'].dropna())

gb_val=GaussianBayes()
gb_val.train(X,Y)
pclasses_val, _ = gb_val.test(X_val)
acc_val = np.sum(pclasses_val == Y_val) / float(pclasses_val.shape[0])

assert_greater_equal(acc_val, 0.90, msg="Acc must be greater then 90%")

cls =gb.predict(np.array([2,2,2,2]).reshape((1,4)))
assert_is_not_none(cls, msg="Predict should work for single example")

print ("All cases passed !")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 from nose.tools import assert_greater_equal, assert_is_not_none
#       2 import pandas as pd
#       3 data=pd.read_csv('./iris.data')
#
# File C:\ProgramData\anaconda3\Lib\site-packages\nose\__init__.py:1
# ----> 1 from nose.core import collector, main, run, run_exit, runmodule
#       2 # backwards compatibility
#       3 from nose.exc import SkipTest, DeprecatedTest
#
# File C:\ProgramData\anaconda3\Lib\site-packages\nose\core.py:12
#       9 import unittest
#      11 from nose.config import Config, all_config_files
# ---> 12 from nose.loader import defaultTestLoader
#      13 from nose.plugins.manager import PluginManager, DefaultPluginManager, \
#      14      RestrictedPluginManager
#      15 from nose.result import TextTestResult
#
# File C:\ProgramData\anaconda3\Lib\site-packages\nose\loader.py:21
#      19 from nose.failure import Failure
#      20 from nose.config import Config
# ---> 21 from nose.importer import Importer, add_path, remove_path
#      22 from nose.selector import defaultSelector, TestAddress
#      23 from nose.util import func_lineno, getpackage, isclass, isgenerator, \
#      24     ispackage, regex_last_key, resolve_name, transplant_func, \
#      25     transplant_class, test_address
#
# File C:\ProgramData\anaconda3\Lib\site-packages\nose\importer.py:12
#       9 import sys
#      10 from nose.config import Config
# ---> 12 from imp import find_module, load_module, acquire_lock, release_lock
#      14 log = logging.getLogger(__name__)
#      16 try:
#
# ModuleNotFoundError: No module named 'imp'

# %% [markdown]
# What can you conclude ?
# ====================

# %% [markdown]
# ## Let's change the features...

# %%
features=[0, 1]
gb.train(Xtrain[:,features],Ytrain)
pclasses,res=gb.test(Xtest[:,features])
print ("Accuracy = ", np.sum(pclasses==Ytest)/float(Ytest.shape[0]))
# Out:
# ['Iris-setosa' 'Iris-versicolor' 'Iris-virginica']
# Accuracy =  0.8

# %% [markdown]
# Remember Features are the important !!
# ======================

# %%
t.plot_decision_regions(Xtest[:,features],Ytest,clf=gb, res=0.02, cycle_marker=True, legend=1)
# Out:
# ['Iris-setosa' 'Iris-versicolor' 'Iris-virginica']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 t.plot_decision_regions(Xtest[:,features],Ytest,clf=gb, res=0.02, cycle_marker=True, legend=1)
#
# File ~\Downloads\i220626_A2_AI-B_ML\i220626_A2_AI-B_ML\Fall24_assignment-2\tools.py:694, in plot_decision_regions(X, y, clf, res, cycle_marker, legend)
#     692 le = LabelEncoder()
#     693 Z = le.fit_transform(Z) # Fit and transform the labels # only used here to encode them
# --> 694 plt.contourf(xx, yy, Z, alpha=0.4, cmap=cmap)
#     695 plt.xlim(xx.min(), xx.max())
#     696 plt.ylim(yy.min(), yy.max())
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\pyplot.py:2950, in contourf(data, *args, **kwargs)
#    2948 @_copy_docstring_and_deprecators(Axes.contourf)
#    2949 def contourf(*args, data=None, **kwargs) -> QuadContourSet:
# -> 2950     __ret = gca().contourf(
#    2951         *args, **({"data": data} if data is not None else {}), **kwargs
#    2952     )
#    2953     if __ret._A is not None:  # type: ignore[attr-defined]
#    2954         sci(__ret)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\__init__.py:1465, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1462 @functools.wraps(func)
#    1463 def inner(ax, *args, data=None, **kwargs):
#    1464     if data is None:
# -> 1465         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1467     bound = new_sig.bind(ax, *args, **kwargs)
#    1468     auto_label = (bound.arguments.get(label_namer)
#    1469                   or bound.kwargs.get(label_namer))
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:6536, in Axes.contourf(self, *args, **kwargs)
#    6527 """
#    6528 Plot filled contours.
#    6529
#    (...)
#    6533 %(contour_doc)s
#    6534 """
#    6535 kwargs['filled'] = True
# -> 6536 contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    6537 self._request_autoscale_view()
#    6538 return contours
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\contour.py:858, in ContourSet.__init__(self, ax, levels, filled, linewidths, linestyles, hatches, alpha, origin, extent, cmap, colors, norm, vmin, vmax, extend, antialiased, nchunk, locator, transform, negative_linestyles, clip_path, *args, **kwargs)
#     854 if self.negative_linestyles is None:
#     855     self.negative_linestyles = \
#     856         mpl.rcParams['contour.negative_linestyle']
# --> 858 kwargs = self._process_args(*args, **kwargs)
#     859 self._process_levels()
#     861 self._extend_min = self.extend in ['min', 'both']
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\contour.py:1523, in QuadContourSet._process_args(self, corner_mask, algorithm, *args, **kwargs)
#    1520         corner_mask = mpl.rcParams['contour.corner_mask']
#    1521 self._corner_mask = corner_mask
# -> 1523 x, y, z = self._contour_args(args, kwargs)
#    1525 contour_generator = contourpy.contour_generator(
#    1526     x, y, z, name=self._algorithm, corner_mask=self._corner_mask,
#    1527     line_type=contourpy.LineType.SeparateCode,
#    1528     fill_type=contourpy.FillType.OuterCode,
#    1529     chunk_size=self.nchunk)
#    1531 t = self.get_transform()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\contour.py:1563, in QuadContourSet._contour_args(self, args, kwargs)
#    1561 elif 2 < nargs <= 4:
#    1562     x, y, z_orig, *args = args
# -> 1563     x, y, z = self._check_xyz(x, y, z_orig, kwargs)
#    1565 else:
#    1566     raise _api.nargs_error(fn, takes="from 1 to 4", given=nargs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\contour.py:1589, in QuadContourSet._check_xyz(self, x, y, z, kwargs)
#    1586 z = ma.asarray(z)
#    1588 if z.ndim != 2:
# -> 1589     raise TypeError(f"Input z must be 2D, not {z.ndim}D")
#    1590 if z.shape[0] < 2 or z.shape[1] < 2:
#    1591     raise TypeError(f"Input z must be at least a (2, 2) shaped array, "
#    1592                     f"but has shape {z.shape}")
#
# TypeError: Input z must be 2D, not 1D

# %% [markdown]
# ## Goal: Find the best pair of features (that gives maximum mean cross-validation accuracy) from all the available pairs for the problem in hand

# %%
acc = []
gb=GaussianBayes()
for i in range(4):
    for j in range(4):
       if i != j:
           features = [i,j]
           gb.train(Xtrain[:,features],Ytrain)
           pclasses,res=gb.test(Xtest[:,features])
           acc.append((np.sum(pclasses==Ytest)/float(Ytest.shape[0]), (i,j)))
print("Accuracies for all possible pairs: " ,acc)
